# %%
import glob
import pandas as pd
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-84c73103-4980-4fa0-9957-079e5c0a1f31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84c73103-4980-4fa0-9957-079e5c0a1f31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datatran2020.csv to datatran2020.csv
# Saving datatran2019.csv to datatran2019.csv
# Saving datatran2018.csv to datatran2018.csv
# Saving datatran2017.csv to datatran2017.csv

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "datatran2020.csv" with length 10749818 bytes
# User uploaded file "datatran2019.csv" with length 18129710 bytes
# User uploaded file "datatran2018.csv" with length 18803451 bytes
# User uploaded file "datatran2017.csv" with length 24026333 bytes

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]


combined_csv = pd.concat([pd.read_csv(f, sep=';',encoding='latin-1') for f in all_filenames ])

# %%
combined_csv.drop_duplicates()
combined_csv
# Out:
#              id  ... ,id,data_inversa,dia_semana,horario,uf,br,km,municipio,causa_acidente,tipo_acidente,classificacao_acidente,fase_dia,sentido_via,condicao_metereologica,tipo_pista,tracado_via,uso_solo,pessoas,mortos,feridos_leves,feridos_graves,ilesos,ignorados,feridos,veiculos,latitude,longitude,regional,delegacia,uop
# 0       99973.0  ...                                                NaN
# 1       99976.0  ...                                                NaN
# 2       99977.0  ...                                                NaN
# 3       99981.0  ...                                                NaN
# 4       99982.0  ...                                                NaN
# ...         ...  ...                                                ...
# 266008      NaN  ...  67441,266255.0,2019-10-07,segunda-feira,09:10:...
# 266009      NaN  ...  67442,266406.0,2019-11-25,segunda-feira,07:20:...
# 266010      NaN  ...  67443,266434.0,2019-06-03,segunda-feira,19:00:...
# 266011      NaN  ...  67444,266573.0,2019-07-13,sÃ¡bado,19:35:00,PR,...
# 266012      NaN  ...  67445,266627.0,2019-10-22,terÃ§a-feira,20:20:0...
#
# [798039 rows x 31 columns]

# %%
combined_csv.to_csv('detran-2017-2020_CSV.csv')
files.download('detran-2017-2020_CSV.csv')
